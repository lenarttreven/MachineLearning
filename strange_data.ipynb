# %%
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np
import pandas as pd
from cvxpy import *
from sklearn.utils import shuffle

# %%
df = pd.read_csv('ex8a.txt', sep=' |:', header=None, engine='python')
df.columns = ['class', 'c', 'a', 'd', 'b']
df.drop(['c', 'd'], 1, inplace=True)

fig = plt.figure()



first_class = df.loc[df['class'] == 1]
second_class = df.loc[df['class'] == -1]
_, fst_att, snd_att = first_class.columns
one = plt.scatter(first_class[fst_att], first_class[snd_att], color = 'red', label='1')
two = plt.scatter(second_class[fst_att], second_class[snd_att], color = 'blue', label='-1')
fig.legend(handles=[one,two], labels=['1', '-1'])


plt.show()

# %%
import matplotlib
from matplotlib import pyplot as plt
import scipy
from sklearn import svm



X = df[['a', 'b']]
Y  = df['class']


# C = 1.0  # SVM regularization parameter
# clf = svm.SVC(kernel = 'rbf',  gamma=0.7, C=C )
# clf.fit(X, Y)

# h = .02  # step size in the mesh
# # create a mesh to plot in
# x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
# y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
# xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
#                      np.arange(y_min, y_max, h))


# # Plot the decision boundary. For that, we will assign a color to each
# # point in the mesh [x_min, m_max]x[y_min, y_max].
# Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

# # Put the result into a color plot
# Z = Z.reshape(xx.shape)
# plt.contour(xx, yy, Z, cmap=plt.cm.Paired)
X
# Out:
#             a         b
# 0    0.107143  0.603070
# 1    0.093318  0.649854
# 2    0.097926  0.705409
# 3    0.155530  0.784357
# 4    0.210829  0.866228
# 5    0.328341  0.929094
# 6    0.429724  0.934942
# 7    0.620968  0.934942
# 8    0.756912  0.910088
# 9    0.819124  0.879386
# 10   0.809908  0.836988
# 11   0.750000  0.819444
# 12   0.773041  0.854532
# 13   0.770737  0.889620
# 14   0.766129  0.899854
# 15   0.779954  0.835526
# 16   0.750000  0.791667
# 17   0.761521  0.765351
# 18   0.814516  0.832602
# 19   0.814516  0.885234
# 20   0.563364  0.921784
# 21   0.494240  0.899854
# 22   0.480415  0.863304
# 23   0.448157  0.819444
# 24   0.425115  0.857456
# 25   0.450461  0.899854
# 26   0.510369  0.937865
# 27   0.498848  0.945175
# 28   0.351382  0.934942
# 29   0.273041  0.901316
# ..        ...       ...
# 833  0.879032  0.421930
# 834  0.874424  0.407895
# 835  0.927419  0.407895
# 836  0.948157  0.411404
# 837  0.961982  0.413158
# 838  0.966590  0.425439
# 839  0.966590  0.434211
# 840  0.948157  0.434211
# 841  0.934332  0.435965
# 842  0.948157  0.469298
# 843  0.964286  0.474561
# 844  0.989631  0.453509
# 845  0.987327  0.435965
# 846  0.966590  0.516667
# 847  0.959677  0.557018
# 848  0.904378  0.560526
# 849  0.915899  0.525439
# 850  0.922811  0.493860
# 851  0.911290  0.453509
# 852  0.890553  0.444737
# 853  0.874424  0.507895
# 854  0.897465  0.527193
# 855  0.913594  0.537719
# 856  0.968894  0.565789
# 857  0.985023  0.579825
# 858  0.994240  0.516667
# 859  0.964286  0.472807
# 860  0.975806  0.439474
# 861  0.989631  0.425439
# 862  0.996544  0.414912
#
# [863 rows x 2 columns]

# %%
df = pd.read_csv('bezdekIris.txt', sep=",", header=None)
df.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'clas' ]

df = df[df.clas != 'Iris-versicolor']
df = df.rename(columns={'clas': 'class',})


df.replace({'Iris-setosa': 1, 'Iris-virginica': -1,}, inplace=True)
df.reset_index(inplace=True, drop=True)

# %%
df[45:55]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  class
# 45           4.8          3.0           1.4          0.3      1
# 46           5.1          3.8           1.6          0.2      1
# 47           4.6          3.2           1.4          0.2      1
# 48           5.3          3.7           1.5          0.2      1
# 49           5.0          3.3           1.4          0.2      1
# 50           6.3          3.3           6.0          2.5     -1
# 51           5.8          2.7           5.1          1.9     -1
# 52           7.1          3.0           5.9          2.1     -1
# 53           6.3          2.9           5.6          1.8     -1
# 54           6.5          3.0           5.8          2.2     -1

# %%
x1 = 10 + np.random.normal(1, 4, 1000)
y1 = np.random.normal(1, 1, 1000)

x2 = np.random.normal(1, 4, 1000)
y2 = np.random.normal(1, 1, 1000)

fig = plt.figure()

width = 12
height = 9
plt.figure(figsize=(width, height))





plt.scatter(x1, y1,color = 'red')
plt.scatter(x2, y2, color = 'blue')





plt.show()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el74949097335925874415976"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el74949097335925874415976", {"id": "el7494909733592", "height": 288.0, "data": {}, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "width": 432.0, "axes": []});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.js", function(){
#
#          mpld3.draw_figure("fig_el74949097335925874415976", {"id": "el7494909733592", "height": 288.0, "data": {}, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "width": 432.0, "axes": []});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://mpld3.github.io/js/d3.v3.min.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.js", function(){
#
#                  mpld3.draw_figure("fig_el74949097335925874415976", {"id": "el7494909733592", "height": 288.0, "data": {}, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "width": 432.0, "axes": []});
#             })
#          });
# }
# </script>

# %%
x1 = 10 + np.random.normal(1, 4, 1000)
y1 = np.random.normal(1, 1, 1000)

x2 = np.random.normal(1, 4, 1000)
y2 = np.random.normal(1, 1, 1000)

plt.scatter(x1, y1,color = 'red')
plt.scatter(x2, y2, color = 'blue')

y = np.arange(-3, 5, 0.01)
x = [5] * len(y)

plt.plot(x, y, color='black', linewidth=3.0)

plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn import svm
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt


# Create arbitrary dataset for example
df = pd.DataFrame({'Planned_End': np.random.uniform(low=-5, high=5, size=50),
                   'Actual_End':  np.random.uniform(low=-1, high=1, size=50),
                   'Late':        np.random.random_integers(low=0,  high=2, size=50)}
)

# Fit Support Vector Machine Classifier
X = df[['Planned_End', 'Actual_End']]
y = df['Late']

clf = svm.SVC(decision_function_shape='ovo')
clf.fit(X.values, y.values) 

# Plot Decision Region using mlxtend's awesome plotting function
plot_decision_regions(X=X.values, 
                      y=y.values,
                      clf=clf, 
                      legend=2)

# Update plot object with X/Y axis labels and Figure Title
plt.xlabel(X.columns[0], size=14)
plt.ylabel(X.columns[1], size=14)
plt.title('SVM Decision Region Boundary', size=16)
# Out:
# /Users/lenarttreven/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:11: DeprecationWarning: This function is deprecated. Please call randint(0, 2 + 1) instead

# %%
import numpy as np
import pandas as pd
from sklearn import svm
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt


df = pd.read_csv('ex8a.txt', sep=' |:', header=None, engine='python')
df.columns = ['class', 'c', 'a', 'd', 'b']
df.drop(['c', 'd'], 1, inplace=True)

X = df[['a', 'b']]
y = df['class']
clf = svm.SVC(C=10, kernel='rbf', gamma=100)
clf.fit(X.values, y.values) 

plot_decision_regions(X=X.values, 
                      y=y.values,
                      clf=clf, 
                      legend=2)

plt.xlabel(X.columns[0], size=16)
plt.ylabel(X.columns[1], size=16)
plt.title('SVM Decision Region Boundary', size=16)

# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import scipy
from sklearn import svm


mu_vec1 = np.array([0,0])
cov_mat1 = np.array([[2,0],[0,2]])
x1_samples = np.random.multivariate_normal(mu_vec1, cov_mat1, 100)
mu_vec1 = mu_vec1.reshape(1,2).T # to 1-col vector

mu_vec2 = np.array([1,2])
cov_mat2 = np.array([[1,0],[0,1]])
x2_samples = np.random.multivariate_normal(mu_vec2, cov_mat2, 100)
mu_vec2 = mu_vec2.reshape(1,2).T


fig = plt.figure()


plt.scatter(x1_samples[:,0],x1_samples[:,1], marker='+', label='+')
plt.scatter(x2_samples[:,0],x2_samples[:,1], c= 'green', marker='o', label='o')

X = np.concatenate((x1_samples,x2_samples), axis = 0)
Y = np.array([0]*100 + [1]*100)

# %%
C = 1.0  # SVM regularization parameter
clf = svm.SVC(kernel = 'rbf',  gamma=0.7, C=C )
clf.fit(X, Y)

h = .02  # step size in the mesh
# create a mesh to plot in
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))


# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, m_max]x[y_min, y_max].
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contour(xx, yy, Z, cmap=plt.cm.Paired)
plt.legend(loc='best')
plt.show()

# %%
df = pd.read_csv('ex8a.txt', sep=' |:', header=None, engine='python')
df.columns = ['class', 'c', 'a', 'd', 'b']
df.drop(['c', 'd'], 1, inplace=True)

first_class = df.loc[df['class'] == 1]
second_class = df.loc[df['class'] == -1]
_, fst_att, snd_att = first_class.columns
plt.scatter(first_class[fst_att], first_class[snd_att], color = 'red')
plt.scatter(second_class[fst_att], second_class[snd_att], color = 'blue')

plt.show()

# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import scipy
from sklearn import svm
import mpld3
mpld3.enable_notebook()





df = pd.read_csv('ex8a.txt', sep=' |:', header=None, engine='python')
df.columns = ['class', 'c', 'a', 'd', 'b']
df.drop(['c', 'd'], 1, inplace=True)

first_class = df.loc[df['class'] == 1]
second_class = df.loc[df['class'] == -1]
_, fst_att, snd_att = first_class.columns

X = np.array(df[['a', 'b']])
Y = np.array(df['class'])

fig = plt.figure()

width = 12
height = 9
plt.figure(figsize=(width, height))


plt.scatter(first_class[fst_att], first_class[snd_att], color = 'red')
plt.scatter(second_class[fst_att], second_class[snd_att], color = 'blue')


C = 1.0  # SVM regularization parameter
clf = svm.SVC(kernel = 'rbf',  gamma=100, C=C )
clf.fit(X, Y)

h = .02  # step size in the mesh
# create a mesh to plot in
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))


# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, m_max]x[y_min, y_max].
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contour(xx, yy, Z, cmap=plt.cm.Paired)
plt.show()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el74948309198725407655766"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el74948309198725407655766", {"id": "el7494830919872", "height": 288.0, "data": {}, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "width": 432.0, "axes": []});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.js", function(){
#
#          mpld3.draw_figure("fig_el74948309198725407655766", {"id": "el7494830919872", "height": 288.0, "data": {}, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "width": 432.0, "axes": []});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://mpld3.github.io/js/d3.v3.min.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.js", function(){
#
#                  mpld3.draw_figure("fig_el74948309198725407655766", {"id": "el7494830919872", "height": 288.0, "data": {}, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "width": 432.0, "axes": []});
#             })
#          });
# }
# </script>

# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import scipy
from sklearn import svm
import mpld3
mpld3.enable_notebook()





x1 = 10 + np.random.normal(1, 4, 1000)
y1 = np.random.normal(1, 1, 1000)

x2 = np.random.normal(1, 4, 1000)
y2 = np.random.normal(1, 1, 1000)


mu_vec1 = np.array([0,0])
cov_mat1 = np.array([[1,0],[0,1]])
x1_samples = np.random.multivariate_normal(mu_vec1, cov_mat1, 1000)
mu_vec1 = mu_vec1.reshape(1,2).T # to 1-col vector

mu_vec2 = np.array([3,0])
cov_mat2 = np.array([[1,0],[0,1]])
x2_samples = np.random.multivariate_normal(mu_vec2, cov_mat2, 1000)
mu_vec2 = mu_vec2.reshape(1,2).T


fig = plt.figure()

width = 12
height = 9
plt.figure(figsize=(width, height))


plt.scatter(x1_samples[:,0],x1_samples[:,1], color='red')
plt.scatter(x2_samples[:,0],x2_samples[:,1], color= 'blue')

X = np.concatenate((x1_samples,x2_samples), axis = 0)
Y = np.array([0]*1000 + [1]*1000)

C = 1.0  # SVM regularization parameter
clf = svm.SVC(kernel = 'linear',  gamma=100, C=C )
clf.fit(X, Y)

h = .02  # step size in the mesh
# create a mesh to plot in
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))


# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, m_max]x[y_min, y_max].
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contour(xx, yy, Z, cmap=plt.cm.Paired)
plt.show()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el74949110659688777287597"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el74949110659688777287597", {"id": "el7494911065968", "height": 288.0, "data": {}, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "width": 432.0, "axes": []});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.js", function(){
#
#          mpld3.draw_figure("fig_el74949110659688777287597", {"id": "el7494911065968", "height": 288.0, "data": {}, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "width": 432.0, "axes": []});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://mpld3.github.io/js/d3.v3.min.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.js", function(){
#
#                  mpld3.draw_figure("fig_el74949110659688777287597", {"id": "el7494911065968", "height": 288.0, "data": {}, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "width": 432.0, "axes": []});
#             })
#          });
# }
# </script>

# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import scipy
from sklearn import svm
import mpld3
mpld3.enable_notebook()





x1 = 10 + np.random.normal(1, 4, 1000)
y1 = np.random.normal(1, 1, 1000)

x2 = np.random.normal(1, 4, 1000)
y2 = np.random.normal(1, 1, 1000)


mu_vec1 = np.array([0,0])
cov_mat1 = np.array([[1,0],[0,1]])
x1_samples = np.random.multivariate_normal(mu_vec1, cov_mat1, 1000)
mu_vec1 = mu_vec1.reshape(1,2).T # to 1-col vector

mu_vec2 = np.array([3,0])
cov_mat2 = np.array([[1,0],[0,1]])
x2_samples = np.random.multivariate_normal(mu_vec2, cov_mat2, 1000)
mu_vec2 = mu_vec2.reshape(1,2).T


fig = plt.figure()

width = 12
height = 9
plt.figure(figsize=(width, height))


plt.scatter(x1_samples[:,0],x1_samples[:,1], color='red')
plt.scatter(x2_samples[:,0],x2_samples[:,1], color= 'blue')

X = np.concatenate((x1_samples,x2_samples), axis = 0)
Y = np.array([0]*1000 + [1]*1000)



plt.show()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el7494910547688846870272"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el7494910547688846870272", {"id": "el7494910547688", "height": 288.0, "data": {}, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "width": 432.0, "axes": []});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.js", function(){
#
#          mpld3.draw_figure("fig_el7494910547688846870272", {"id": "el7494910547688", "height": 288.0, "data": {}, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "width": 432.0, "axes": []});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://mpld3.github.io/js/d3.v3.min.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.js", function(){
#
#                  mpld3.draw_figure("fig_el7494910547688846870272", {"id": "el7494910547688", "height": 288.0, "data": {}, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "width": 432.0, "axes": []});
#             })
#          });
# }
# </script>

# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import scipy
from sklearn import svm
import mpld3
mpld3.enable_notebook()


x1 = np.random.rand(50, 2)
x2 = np.random.rand(50, 2) 
x2 = (0,1.5) + x2

x = np.concatenate((x1, x2), axis = 0)

y = np.array([1] * 50 + [-1] * 50)

df1 = pd.DataFrame(x)

df1.columns = ['1', '2']
df1['razred'] = y

fig = plt.figure()

width = 12
height = 9
plt.figure(figsize=(width, height))

first_class = df1.loc[df1['razred'] == 1]
second_class = df1.loc[df1['razred'] == -1]
fst_att, snd_att, _ = first_class.columns
plt.scatter(first_class[fst_att], first_class[snd_att], color = 'blue', s=50)
plt.scatter(second_class[fst_att], second_class[snd_att], color = 'red', s=50)



t = np.arange(-0.2, 1.2, 0.01)
s = 0.4 * t + 1.25
plt.plot(t, s, 'black', linewidth=4.0)

plt.show()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el74948311509363939173067"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el74948311509363939173067", {"id": "el7494831150936", "height": 288.0, "data": {}, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "width": 432.0, "axes": []});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.js", function(){
#
#          mpld3.draw_figure("fig_el74948311509363939173067", {"id": "el7494831150936", "height": 288.0, "data": {}, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "width": 432.0, "axes": []});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://mpld3.github.io/js/d3.v3.min.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.js", function(){
#
#                  mpld3.draw_figure("fig_el74948311509363939173067", {"id": "el7494831150936", "height": 288.0, "data": {}, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "width": 432.0, "axes": []});
#             })
#          });
# }
# </script>

# %%
df1 = pd.DataFrame(x)

df1.columns = ['1', '2']
df1['razred'] = y

fig = plt.figure()

width = 12
height = 9
plt.figure(figsize=(width, height))

first_class = df1.loc[df1['razred'] == 1]
second_class = df1.loc[df1['razred'] == -1]
fst_att, snd_att, _ = first_class.columns
plt.scatter(first_class[fst_att], first_class[snd_att], color = 'blue', s=50)
plt.scatter(second_class[fst_att], second_class[snd_att], color = 'red', s=50)



t = np.arange(-0.2, 1.2, 0.01)
s1 = 0 * t + 1.5
s2 = 0 * t + 1
s3 = 0 * t + 1.25
plt.plot(t, s1, 'r--', linewidth=3.0)
plt.plot(t, s2, 'b--', linewidth=3.0)
plt.plot(t, s3, 'black', linewidth=3.0)



plt.show()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el74947866928404649506527"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el74947866928404649506527", {"id": "el7494786692840", "height": 648.0, "data": {}, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "width": 864.0, "axes": []});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.js", function(){
#
#          mpld3.draw_figure("fig_el74947866928404649506527", {"id": "el7494786692840", "height": 648.0, "data": {}, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "width": 864.0, "axes": []});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://mpld3.github.io/js/d3.v3.min.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.js", function(){
#
#                  mpld3.draw_figure("fig_el74947866928404649506527", {"id": "el7494786692840", "height": 648.0, "data": {}, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "width": 864.0, "axes": []});
#             })
#          });
# }
# </script>

# %%
df1.loc[df['class'] == 1]
# Out:
#            1         2  class
# 0   0.680713  0.944756      1
# 1   0.672220  0.718394      1
# 2   0.188779  0.751055      1
# 3   0.097066  0.035271      1
# 4   0.264846  0.764459      1
# 5   0.532527  0.454606      1
# 6   0.172369  0.798283      1
# 7   0.123701  0.500955      1
# 8   0.874748  0.584986      1
# 9   0.898886  0.341986      1
# 10  0.989927  0.706143      1
# 11  0.277711  0.704702      1
# 12  0.097918  0.180090      1
# 13  0.880958  0.491271      1
# 14  0.707699  0.196559      1
# 15  0.547038  0.325407      1
# 16  0.431347  0.285731      1
# 17  0.582084  0.599959      1
# 18  0.068791  0.967489      1
# 19  0.315673  0.461273      1
# 20  0.825161  0.362317      1
# 21  0.317217  0.119721      1
# 22  0.763460  0.983913      1
# 23  0.954495  0.580680      1
# 24  0.456366  0.198702      1
# 25  0.708471  0.519705      1
# 26  0.829431  0.693051      1
# 27  0.338847  0.964237      1
# 28  0.664235  0.025291      1
# 29  0.755950  0.961244      1
# ..       ...       ...    ...
# 70  1.838991  1.835036     -1
# 71  1.914717  1.390067     -1
# 72  1.919546  1.947961     -1
# 73  1.610107  1.804470     -1
# 74  1.240692  1.069225     -1
# 75  1.957297  1.160519     -1
# 76  1.821973  1.513477     -1
# 77  1.769316  1.103974     -1
# 78  1.504593  1.931367     -1
# 79  1.194083  1.726229     -1
# 80  1.471654  1.831382     -1
# 81  1.070658  1.601112     -1
# 82  1.136696  1.239845     -1
# 83  1.036585  1.445472     -1
# 84  1.373129  1.363043     -1
# 85  1.055331  1.635636     -1
# 86  1.207039  1.861172     -1
# 87  1.249213  1.865887     -1
# 88  1.987778  1.558627     -1
# 89  1.981709  1.023834     -1
# 90  1.277673  1.683803     -1
# 91  1.834539  1.696368     -1
# 92  1.227731  1.119451     -1
# 93  1.224528  1.037857     -1
# 94  1.283732  1.683160     -1
# 95  1.821065  1.045148     -1
# 96  1.586799  1.155435     -1
# 97  1.084065  1.981300     -1
# 98  1.510241  1.912660     -1
# 99  1.527424  1.360359     -1
#
# [100 rows x 3 columns]

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.set_title('ADR vs Rating (CS:GO)')
ax.scatter(x=data[:,0],y=data[:,1],label='Data')
plt.plot(data[:,0], m*data[:,0] + b,color='red',label='Our Fitting 
Line')
ax.set_xlabel('ADR')
ax.set_ylabel('Rating')
ax.legend(loc='best')
plt.show()
# Out:
#   File "<ipython-input-113-01bfe72009a0>", line 5
#     plt.plot(data[:,0], m*data[:,0] + b,color='red',label='Our Fitting
#                                                                        ^
# SyntaxError: EOL while scanning string literal

# %%
df = pd.read_csv('bezdekIris.txt', sep=",", header=None)
df.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'clas' ]

df = df[df.clas != 'Iris-virginica']
df = df.rename(columns={'clas': 'class',})


df.replace({'Iris-setosa': 1, 'Iris-versicolor': -1,}, inplace=True)
df.reset_index()

df[45:55]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  class
# 45           4.8          3.0           1.4          0.3      1
# 46           5.1          3.8           1.6          0.2      1
# 47           4.6          3.2           1.4          0.2      1
# 48           5.3          3.7           1.5          0.2      1
# 49           5.0          3.3           1.4          0.2      1
# 50           7.0          3.2           4.7          1.4     -1
# 51           6.4          3.2           4.5          1.5     -1
# 52           6.9          3.1           4.9          1.5     -1
# 53           5.5          2.3           4.0          1.3     -1
# 54           6.5          2.8           4.6          1.5     -1

# %%
import matplotlib.pyplot as plt
from numpy.random import random

colors = ['b', 'c', 'y', 'm', 'r']

lo = plt.scatter(random(10), random(10), marker='x', color=colors[0])
ll = plt.scatter(random(10), random(10), marker='o', color=colors[0])
l  = plt.scatter(random(10), random(10), marker='o', color=colors[1])
a  = plt.scatter(random(10), random(10), marker='o', color=colors[2])
h  = plt.scatter(random(10), random(10), marker='o', color=colors[3])
hh = plt.scatter(random(10), random(10), marker='o', color=colors[4])
ho = plt.scatter(random(10), random(10), marker='x', color=colors[4])

plt.legend((lo, ll, l, a, h, hh, ho),
           ('Low Outlier', 'LoLo', 'Lo', 'Average', 'Hi', 'HiHi', 'High Outlier'),
           scatterpoints=1,
           loc='lower left',
           ncol=3,
           fontsize=8)

plt.show()
